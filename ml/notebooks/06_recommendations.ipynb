# %%
print("""
Notebook 06 — Recommendation Engine

Status: Deferred — Phase 3 MVP

Reason:
  Collaborative filtering requires real user-property interaction data.
  No interactions exist until the web/mobile frontend is live with real users.

What is implemented instead:
  Content-based similarity in the ML service (/api/v1/ml/recommend endpoint).
  Given a property_id, returns top 5 similar properties by:
    - Same city
    - Price within 30% range
    - Same property type
    - Closest bedroom count
    - Highest amenity count overlap
  No model file needed — pure feature matching at query time.

Future work (Phase 6 — after real user data):
  - Collect: user views, saves, contact requests
  - Train: matrix factorisation (SVD) on user-property interaction matrix
  - Serve: personalised recommendations per user_id
  - Evaluate: precision@k, recall@k, NDCG
""")
# Out:
# Notebook 06 — Recommendation Engine
#
# Status: Deferred — Phase 3 MVP
#
# Reason:
#   Collaborative filtering requires real user-property interaction data.
#   No interactions exist until the web/mobile frontend is live with real users.
#
# What is implemented instead:
#   Content-based similarity in the ML service (/api/v1/ml/recommend endpoint).
#   Given a property_id, returns top 5 similar properties by:
#     - Same city
#     - Price within 30% range
#     - Same property type
#     - Closest bedroom count
#     - Highest amenity count overlap
#   No model file needed — pure feature matching at query time.
#
# Future work (Phase 6 — after real user data):
#   - Collect: user views, saves, contact requests
#   - Train: matrix factorisation (SVD) on user-property interaction matrix
#   - Serve: personalised recommendations per user_id
#   - Evaluate: precision@k, recall@k, NDCG
